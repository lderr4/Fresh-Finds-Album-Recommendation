# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
reviews = pd.read_json("mard/mard_reviews.json" , lines=True)
content = pd.read_json("mard/mard_metadata.json", lines=True)

# %%
content[content["artist"] == "Chet Baker"]
# Out:
#        price                           artist-mbid  \
# 18762  28.36  1ba1d493-7114-45e2-b163-a36d49a0c065
# 19978   8.99  1ba1d493-7114-45e2-b163-a36d49a0c065
# 19994  10.53  efc99722-cfb7-4619-bb8d-d3563322e030
# 20224   8.99  1ba1d493-7114-45e2-b163-a36d49a0c065
# 20881    NaN  1ba1d493-7114-45e2-b163-a36d49a0c065
# 21096    NaN  1ba1d493-7114-45e2-b163-a36d49a0c065
# 21232    NaN  1ba1d493-7114-45e2-b163-a36d49a0c065
# 22305    NaN  1ba1d493-7114-45e2-b163-a36d49a0c065
# 22440   5.94  1ba1d493-7114-45e2-b163-a36d49a0c065
# 22650    NaN                                   NaN
# 22684    NaN  1ba1d493-7114-45e2-b163-a36d49a0c065
# 22795   7.99  1ba1d493-7114-45e2-b163-a36d49a0c065
# 22908    NaN                                   NaN
# 23314    NaN  1ba1d493-7114-45e2-b163-a36d49a0c065
# 23328  74.87                                   NaN
# 23509    NaN                                   NaN
#
#                                                    imUrl  confidence  \
# ...

# %%
reviews.head()
# Out:
#        reviewerID   amazon-id                 reviewerName helpful  \
# 0  A1OFY4ATO7D13W  0026197898  Jacob Shepich "Neo-Luddite"  [2, 2]
# 1  A2KH83L1F70QR8  0026197898          John Stockton "JLS"  [1, 1]
# 2  A1KGXC7IRLVJR3  0615205399          Amy Elizabeth "Amy"  [0, 0]
# 3  A1BT6LQ9NY6RO3  0615205399      Jasa Swaze "Jasa Swaze"  [1, 1]
# 4  A206OKO2FE2IPL  0615205399                    J. Jenson  [1, 1]
#
#    unixReviewTime                                         reviewText  overall  \
# 0      1355702400  Buy this album. Now.  Don't worry about the re...        5
# 1      1358121600  The Sudden Passion did a great job with this o...        5
# 2      1214438400  I received this CD as a gift a few weeks ago f...        5
# 3      1214352000  I am a beginner and have tried a couple of med...        5
# 4      1229212800  This is coming from a person that didn't belie...        5
#
#     reviewTime                            summary
# ...

# %%
s = reviews['amazon-id'].value_counts().apply(lambda x: np.log(x))
plt.hist(s)  # You can adjust the number of bins as needed
plt.title("Amazon ID Count Histogram")
plt.xlabel("Count")
plt.ylabel("Frequency")
plt.show()
